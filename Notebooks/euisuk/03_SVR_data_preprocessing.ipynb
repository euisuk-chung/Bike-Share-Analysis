# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv('../../Data/daily_user_cnt.csv')

# %%
holidays = pd.read_csv('../../Data/kor_holidays.csv')

# %%
holidays = holidays[['date', 'is_holiday']]

# %%
# import plotly
import plotly.express as px

fig=px.line(df,x='date',y='cnt', title='bike use')
fig.show()
# Out:
# <div>
#
#
#             <div id="94cee855-031f-4f24-b1bd-c1feca892b22" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("94cee855-031f-4f24-b1bd-c1feca892b22")) {
#                     Plotly.newPlot(
#                         '94cee855-031f-4f24-b1bd-c1feca892b22',
# ...

# %%
df.shape
# Out:
# (730, 2)

# %%
holidays.shape
# Out:
# (53, 2)

# %%
df.head()
# Out:
#          date  cnt
# 0  2018-01-01    9
# 1  2018-01-02   22
# 2  2018-01-03   23
# 3  2018-01-04   11
# 4  2018-01-05   21

# %%
df.tail()
# Out:
#            date  cnt
# 725  2019-12-27   81
# 726  2019-12-28   79
# 727  2019-12-29   61
# 728  2019-12-30   77
# 729  2019-12-31   39

# %%
holidays.head()
# Out:
#          date  is_holiday
# 0  2018-01-01           1
# 1  2018-02-15           1
# 2  2018-02-16           1
# 3  2018-02-17           1
# 4  2018-03-01           1

# %%
holidays.tail()
# Out:
#           date  is_holiday
# 48  2020-10-01           1
# 49  2020-10-02           1
# 50  2020-10-03           1
# 51  2020-10-09           1
# 52  2020-12-25           1

# %%
df[['year','month', 'day']] = df.date.str.split("-",expand=True,)
df.head()
# Out:
#          date  cnt  year month day
# 0  2018-01-01    9  2018    01  01
# 1  2018-01-02   22  2018    01  02
# 2  2018-01-03   23  2018    01  03
# 3  2018-01-04   11  2018    01  04
# 4  2018-01-05   21  2018    01  05

# %%
df['weekday'] = pd.to_datetime(df['date']).dt.weekday
df['weeknum'] = pd.to_datetime(df['date']).dt.week

# %%
df.head()
# Out:
#          date  cnt  year month day  weekday  weeknum
# 0  2018-01-01    9  2018    01  01        0        1
# 1  2018-01-02   22  2018    01  02        1        1
# 2  2018-01-03   23  2018    01  03        2        1
# 3  2018-01-04   11  2018    01  04        3        1
# 4  2018-01-05   21  2018    01  05        4        1

# %%
df_hol = pd.merge(df, holidays, how = 'left', on = 'date')

# %%
df_hol.head()
# Out:
#          date  cnt  year month day  weekday  weeknum  is_holiday
# 0  2018-01-01    9  2018    01  01        0        1         1.0
# 1  2018-01-02   22  2018    01  02        1        1         NaN
# 2  2018-01-03   23  2018    01  03        2        1         NaN
# 3  2018-01-04   11  2018    01  04        3        1         NaN
# 4  2018-01-05   21  2018    01  05        4        1         NaN

# %%
df_hol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        730 non-null    object
#  1   cnt         730 non-null    int64
#  2   year        730 non-null    object
#  3   month       730 non-null    object
#  4   day         730 non-null    object
#  5   weekday     730 non-null    int64
#  6   weeknum     730 non-null    int64
#  7   is_holiday  35 non-null     float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 51.3+ KB

# %%
df_hol=df_hol.fillna(0)

# %%
df_hol.to_csv('../../Data/daily_usr_cnt_with_holiday.csv', index = False)
