# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../Data/data_extracted(201806_to_202006).csv', encoding = 'cp949')

# %%
df.head(20)
# Out:
#           date  year  month  day  week weekday  borrow_time  station_num  \
# 0   2018-06-01  2018      6    1    22       금           15         1308
# 1   2018-06-01  2018      6    1    22       금           17         1308
# 2   2018-06-01  2018      6    1    22       금           17         1308
# 3   2018-06-01  2018      6    1    22       금           19         1308
# 4   2018-06-01  2018      6    1    22       금           22         1308
# 5   2018-06-01  2018      6    1    22       금           17         1308
# 6   2018-06-01  2018      6    1    22       금           18         1308
# 7   2018-06-01  2018      6    1    22       금            8         1308
# 8   2018-06-01  2018      6    1    22       금           15         1308
# 9   2018-06-01  2018      6    1    22       금           20         1308
# 10  2018-06-01  2018      6    1    22       금           22         1308
# 11  2018-06-01  2018      6    1    22       금            6         1308
# ...

# %%
df.tail()
# Out:
#              대여일자  대여시간  대여소번호           대여소명 대여구분코드 성별 연령대코드  이용건수     운동량  \
# 59915  2019-02-27    17   1308  안암로터리 버스정류장 앞    정기권  F   30대     1   29.19
# 59916  2019-02-27    17   1308  안암로터리 버스정류장 앞    정기권  M   20대     2  153.35
# 59917  2019-02-27    17   1308  안암로터리 버스정류장 앞    정기권  M   40대     2  152.74
# 59918  2019-02-27    18   1308  안암로터리 버스정류장 앞    정기권  M   20대     1   62.65
# 59919  2019-02-27    19   1308  안암로터리 버스정류장 앞    정기권  F   20대     2  243.75
#
#         탄소량    이동거리  이동시간
# 59915  0.31  1340.0     6
# 59916  1.31  5640.0    28
# 59917  1.29  5550.0    25
# 59918  0.52  2260.0    20
# 59919  2.27  9800.0    58

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59920 entries, 0 to 59919
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여일자    59920 non-null  object
#  1   대여시간    59920 non-null  int64
#  2   대여소번호   59920 non-null  int64
#  3   대여소명    59920 non-null  object
#  4   대여구분코드  59920 non-null  object
#  5   성별      39796 non-null  object
#  6   연령대코드   59920 non-null  object
#  7   이용건수    59920 non-null  int64
#  8   운동량     59920 non-null  object
#  9   탄소량     59920 non-null  object
#  10  이동거리    59920 non-null  float64
#  11  이동시간    59920 non-null  int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 5.5+ MB

# %%
for col in df.columns:
    print(col)
    print('unique value: {}'.format(len(df[col].value_counts())))
    empty_df = pd.DataFrame(df[col].value_counts())
    print(df[col].value_counts())
    empty_df.to_csv('./unique_val/%s.csv'%col, encodig = 'cp949')
    print('\n')
# Out:
# 대여일자
# unique value: 898
# 2019-05-26         238
# 2019-05-30         218
# 2019-05-31         218
# 2019-05-24         209
# 2019-05-28         208
#                   ...
# 2018-02-10 0:00      7
# 2018-11-08 0:00      4
# 2019-02-03           3
# 2018-04-23 0:00      3
# 2020-01-07           1
# Name: 대여일자, Length: 898, dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f0fb314db916> in <module>
#       4     empty_df = pd.DataFrame(df[col].value_counts())
#       5     print(df[col].value_counts())
# ----> 6     empty_df.to_csv('./unique_val/%s.csv'%col, encodig = 'cp949')
#       7     print('\n')
#
# TypeError: to_csv() got an unexpected keyword argument 'encodig'

# %%
len(df[col].value_counts())
# Out:
# 402
